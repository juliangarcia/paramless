# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %pylab inline
from scipy.integrate import simps
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from JSAnimation.IPython_display import display_animation

# %%
# %run ../paramless.py

# %% [markdown]
# #Evolution of seasonal flowering strategies

# %% [markdown]
# Here I test the function simulation framework with the example of section 7  in Dieckmann et al. JTB (2006). It analyzes the evolution of seasonal flowering schedules.

# %% [markdown]
# We will evolve a function $x(a)$, where $a \in [0,1]$ (s.t $x(a) > 0 \forall a$  and $\int x(a) da = 1$)

# %% [markdown]
# ##Define fitness and mutations

# %% [markdown]
# We start by defining a mutation that *does not* allow negative values and *preserves the area under the surface* by compensating all perturbances,therby complying with the restriction $\int x(a) da = 1 $ (using: **gaussian_mutation_distribution**)

# %% [markdown]
# $x(a)$ denotes the ammount of flowers produced at time $t$. We normalize $t$ to be between zero and one. Thus domain of $x(\cdot)$ is $(0,1)$.

# %%
domain = np.arange(0.001, 1.0, 0.01)

# %% [markdown]
# We first define the probability of setting seed $p_x(\cdot)$, as follows:

# %%
#alpha, beta, k_function

# %%
def p_x(a, x, k):
    #takes a, and functions x and k
    return math.e**(-x[a]/k(a))

# %% [markdown]
# In the example, function $k(\cdot)$ is a time-dependent carrying capacity, given by $K(a)= 100(2 + \sin2 \pi ((a-1)^2 - \frac{1}{4}))$

# %%
def k(a):
    return 100*(2 + math.sin(2*math.pi*((a-1.0)**2.0 - 0.25)))

# %%
plot(domain, [k(a) for a in domain], label = 'K(a)')
plt.legend(loc='best')
plt.title(r'Carrying capacity $K(a)$')
plt.ylim((99, 305))
plt.xlabel('time')

# %% [markdown]
# We also consider a function $c(e)$, which denotes the factor in which competition affects the schedule of a competing individual. Here $e$, which is a function of a is the mutant's excess flowering. It is assumed that
#
# $c(e(a)) = 2 / (1 + \exp(-\alpha e(a)))$
#
#
# $\alpha$ determines the strenght of the asymmetric competition between mutant and resident.

# %%
def c(e, alpha):
    return 2.0/(1 + math.e**(-alpha*e))

# %% [markdown]
# The birth-rate of a a rare mutant with schedule $x'$ is given by:
#
# $b(x',x) = \int x'(a)c([x'(a)-x(a)]/x(a)^{\beta})p_x (a)da $
#
# Here $\beta$ measures the excess flowering intensity.

# %%
def birth(x_mutant, x_resident, domain, alpha, beta, k_function):
    x_resident_dict = dict(zip(domain, x_resident))
    x_mutant_dict = dict(zip(domain, x_mutant))
    integrand = [x_mutant_dict[a]*c((x_mutant_dict[a]-x_resident_dict[a])/(x_mutant_dict[a]**beta), alpha)*p_x(a, x_resident_dict, k_function) for a in domain]
    return simps(integrand, domain)

# %% [markdown]
# Since death rates are assume to be constant, we can define fitness solely in terms of birth rates:

# %%
def flowering_fitness(x_resident, x_mutant, domain, alpha, beta, k_function, **kwargs):
    fitness_resident = birth(x_resident, x_resident, domain, alpha, beta, k_function)
    fitness_mutant = birth(x_mutant, x_resident, domain, alpha, beta, k_function)
    return fitness_resident, fitness_mutant

# %%
initial_surface = np.ones_like(domain)

# %%
number_of_generations = 100000

# %%
ans, series = evolve(initial_surface, 
                     mutation_function=gaussian_mutation_distribution,
                     iterations=number_of_generations,
                     mutation_epsilon=0.01,
                     domain= domain, 
                     fitness_function=flowering_fitness, 
                     alpha=1.0, beta=0.9, k_function=k,
                     width=0.005, return_time_series=True)
# Out:
# -c:2: RuntimeWarning: overflow encountered in double_scalars

# %%
plot(domain, ans)

# %%
simps(ans, domain)
# Out:
# 1.0101470031437045

# %%
ani = create_video_from_time_series(series, None, domain, filename='/Users/garcia/Desktop/flowering_soft.mp4', approximate_number_of_frames=5000, record_every=100)

# %%
display_animation(ani)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = 1;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img3423304">
#     <br>
#     <input id="_anim_slider3423304" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="anim3423304.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim3423304.slower()">&#8211;</button>
#     <button onclick="anim3423304.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim3423304.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim3423304.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim3423304.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim3423304.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim3423304.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim3423304.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim3423304.faster()">+</button>
#   <form action="#n" name="_anim_loop_select3423304" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   var img_id = "_anim_img3423304";
#   var slider_id = "_anim_slider3423304";
#   var loop_select_id = "_anim_loop_select3423304";
#   var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAHAJJREFUeJzt3X1wVNUZx/FfNKk1oATURknSWYSMEF6ySVOCFjSppWBU\
# hrFasNNK8KWRESnYOtXWqdhxGLStgEVt7ChR2lJnsAWmJrSdlk2LEKKYAAOMgHVriJIKFfGllhBu\
# /7i9twkJEO0me5+9389Mpzm7N5eTX+J5cp6zC2mO4zgCAMCYM5I9AQAAPgkKGADAJAoYAMAkChgA\
# wCQKGADAJAoYAMAkChgAwCQKGADAJAoYAMAkChgAwCQKGADAJAoYAMAkChgAwCQKGADAJAoYAMAk\
# ChgAwCQKGADAJAoYAMAkChgAwCQKGADAJAoYAMAkChgAwCQKGADAJAoYAMCkQBWwjz76SKWlpYpG\
# oyooKNC9997b43Xz5s1Tfn6+CgsL1dTU1M+zBAAEQXqyJ9DZpz/9aW3YsEGZmZk6duyYJk6cqI0b\
# N2rixIn+NbW1tdq3b5/27t2rLVu2aM6cOWpoaEjirAEAyRCoHZgkZWZmSpKOHj2qjo4ODRkypMvz\
# 69at06xZsyRJpaWlOnz4sNra2vp9ngCA5ApcATt+/Lii0aiys7NVXl6ugoKCLs+3trYqLy/PH+fm\
# 5mr//v39PU0AQJIFqoUoSWeccYaam5v17rvvasqUKYrFYiorK+tyjeM4XcZpaWnd7tPTYwCA0ztx\
# jQ2qwO3APIMGDdLVV1+tl19+ucvjOTk5amlp8cf79+9XTk5Oj/dwHEeO4+j+++/3Pw7z/8iBHMiA\
# HE6XgyWBKmAHDx7U4cOHJUn/+te/9Mc//lFFRUVdrpk2bZqeffZZSVJDQ4OysrKUnZ19yvvG4/E+\
# ma815OAiBzLwkIPLag6BaiG+9dZbmjVrlo4fP67jx4/rG9/4hq688kpVV1dLkqqqqlRRUaHa2lqN\
# GDFCAwYM0IoVK5I8awBAMqQ51vaMvZSWluZvh3s6RwsjcnCRAxl4yMHVOYfOa2fQhaKAAQB6x9La\
# GagzsL4Si8WSPYVAIAcXOZCBhxxcVnMIRQEDAKQeWogAAJ+ltZMdGADApFAUMKv93UQjBxc5kIGH\
# HFxWcwhFAQMApB7OwAAAPktrJzswAIBJoShgVvu7iUYOLnIgAw85uKzmEIoCBgBIPZyBAQB8ltZO\
# dmAAAJNCUcCs9ncTjRxc5EAGHnJwWc0hFAUMAJB6OAMDAPgsrZ3swAAAJoWigFnt7yYaObjIgQw8\
# 5OCymkMoChgAIPVwBgYA8FlaO9mBAQBMCkUBs9rfTTRycJEDGXjIwWU1h1AUMABA6uEMDADgs7R2\
# sgMDAJgUigJmtb+baOTgIgcy8JCDy2oOoShgAIDUwxkYAMBnae0M3A6spaVF5eXlGj16tMaMGaNH\
# H3202zWxWEyDBg1SUVGRioqK9OCDDyZhpgCAZApcAcvIyNCSJUu0c+dONTQ06LHHHtPu3bu7XXfF\
# FVeoqalJTU1Nuu+++055T6v93UQjBxc5kIGHHFxWcwhcAbvwwgsVjUYlSQMHDtSoUaP05ptvdrvO\
# yhYXANA3An0GFo/HdcUVV2jnzp0aOHCg/3h9fb2uu+465ebmKicnRz/+8Y9VUFDQ5XMt9XEBICgs\
# rZ3pyZ7Aybz//vu6/vrrtWzZsi7FS5KKi4vV0tKizMxM1dXVafr06dqzZ0+3e1RWVioSiUiSsrKy\
# FI1GVVZWJul/W2bGjBkzDvM4FouppqZGkvz10opA7sDa29t1zTXX6KqrrtL8+fNPe/2wYcO0detW\
# DRkyxH+s828RsVjM/8aFGTm4yIEMPOTg6pyDpR1Y4M7AHMfRLbfcooKCgpMWr7a2Nj/gxsZGOY7T\
# pXgBAFJf4HZgGzdu1OWXX65x48YpLS1NkrRo0SK98cYbkqSqqio99thjeuKJJ5Senq7MzEw98sgj\
# mjBhQpf7WPotAgCCwtLaGbgCliiWvgkAEBSW1s7AtRD7gndgGXbk4CIHMvCQg8tqDqEoYACA1EML\
# EQDgs7R2sgMDAJgUigJmtb+baOTgIgcy8JCDy2oOoShgAIDUwxkYAMBnae1kBwYAMCkUBcxqfzfR\
# yMFFDmTgIQeX1RxCUcAAAKmHMzAAgM/S2skODABgUigKmNX+bqKRg4scyMBDDi6rOYSigAEAUg9n\
# YAAAn6W1kx0YAMCkUBQwq/3dRCMHFzmQgYccXFZzCEUBAwCkHs7AAAA+S2snOzAAgEmhKGBW+7uJ\
# Rg4uciADDzm4rOYQigIGAEg9nIEBAHyW1k52YAAAk0JRwKz2dxONHFzkQAYecnBZzSEUBQwAkHo4\
# AwMA+CytnezAAAAmBa6AtbS0qLy8XKNHj9aYMWP06KOP9njdvHnzlJ+fr8LCQjU1NZ3ynlb7u4lG\
# Di5yIAMPObis5pCe7AmcKCMjQ0uWLFE0GtX777+vz33uc5o8ebJGjRrlX1NbW6t9+/Zp79692rJl\
# i+bMmaOGhoYkzhoA0N8CfwY2ffp03Xnnnbryyiv9x26//XaVl5drxowZkqSRI0eqvr5e2dnZ/jWW\
# +rgAEBSW1s7AtRA7i8fjampqUmlpaZfHW1tblZeX549zc3O1f//+/p4eACCJAtdC9Lz//vu6/vrr\
# tWzZMg0cOLDb8yf+hpCWltbtmsrKSkUiEcXjcUWjUUWjUZWVlUn6X883TOPm5mbNnz8/MPNJ1rhz\
# vz8I80nGeOnSpaH/78HT+Wci2fNJ1n8Pixcv1oUXXqhIJ
