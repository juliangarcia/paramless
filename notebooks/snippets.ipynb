# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# %run ../paramless.py

# %% [markdown]
# #Evolving a simple quadratic function

# %%
x = np.linspace(-1.0, 1.0, 100)  
target = target_function(x)

# %%
plot(x, target_function(x))

# %%
initial_surface = np.zeros_like(target)
ans = evolve(initial_surface, target_surface=target, mutation_function=point_mutation, distance_function=one_norm_distance, target_distance=0.001, maximum_iterations=100000, epsilon=0.0001)

# %% [markdown]
# ###After 100000 iterations

# %%
plot(x, ans['evolved_surface'])
plot(x,target)

# %% [markdown]
# ###Lets do more iterations

# %%
initial_surface = np.zeros_like(target)
ans, time_series = evolve(initial_surface, target_surface=target, mutation_function=point_mutation, distance_function=one_norm_distance, target_distance=0.005, maximum_iterations=100000, return_time_series=True, epsilon=0.001)

# %%
plot(x, ans['evolved_surface'])

# %% [markdown]
# ###And even more iterations

# %%
initial_surface = np.zeros_like(x)
ans, series = evolve(initial_surface, target_surface=target, mutation_function=point_mutation, distance_function=one_norm_distance, target_distance=0.01, maximum_iterations=10000000, record_interval=2000, epsilon=0.005, return_time_series=True)

# %%
create_video_from_time_series(series, target_surface=target, domain=x, filename='/Users/garcia/Desktop/complete.mp4', approximate_number_of_frames=2000)

# %% [markdown]
# We are there but it took forever

# %% [markdown]
# ##Let's make a video!

# %%
# %run ../paramless.py
create_video_from_time_series(time_series, target_surface=target, domain=x, filename='/Users/garcia/Desktop/my_video.mp4', approximate_number_of_frames=200)
