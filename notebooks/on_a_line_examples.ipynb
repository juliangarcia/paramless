# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# %run ../paramless.py

# %%
x = np.linspace(-1.0, 1.0, 100)  
target = target_function(x)

# %%
plot(x, target_function(x))

# %%
initial_surface = np.zeros_like(target)
ans, series = evolve(initial_surface=initial_surface, fitness_function=distance_fitness_function, mutation_function=point_mutation, iterations=100000, return_time_series=True, seed=666, target_surface=target, epsilon=0.001)

# %%
plot(x,ans)
plot(x,target)
plt.xlim((-1,1))
plt.ylim((0,1))
# Out:
# (0, 1)

# %%
create_video_from_time_series(series, target_surface=target, domain=x, filename='/Users/garcia/Desktop/new_video.mp4', approximate_number_of_frames=500, record_every=100)
