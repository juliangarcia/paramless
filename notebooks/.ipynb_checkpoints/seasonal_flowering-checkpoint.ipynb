# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %pylab inline
from scipy.integrate import simps
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from JSAnimation.IPython_display import display_animation

# %%
# %run ../seasonal_flowering.py

# %% [markdown]
# #Evolution of seasonal flowering strategies

# %% [markdown]
# Here I test the function simulation framework with the example of section 7  in Dieckmann et al. JTB (2006). It analyzes the evolution of seasonal flowering schedules.

# %% [markdown]
# We will evolve a function $x(a)$, where $a \in [0,1]$ (s.t $x(a) > 0 \forall a$  and $\int x(a) da = 1$)

# %% [markdown]
# ##Define fitness and mutations

# %% [markdown]
# We start by defining a mutation that *does not* allow negative values and *preserves the area under the surface* by compensating all perturbances,therby complying with the restriction $\int x(a) da = 1 $

# %%
def point_mutation_distribution(vector, mutation_epsilon):
    #moves up a random point, and down a random point at the same time
    mutant = np.copy(vector)
    (position_up, position_down) = np.random.randint(len(vector), size=2)
    adjusted_epsilon = mutation_epsilon
    #taking care that no negative values are allowed
    if (mutant[position_down]-mutation_epsilon) <0:
        adjusted_epsilon = mutant[position_down]
    mutant[position_up] = mutant[position_up] + adjusted_epsilon
    mutant[position_down] = mutant[position_down] - adjusted_epsilon
    return mutant

# %% [markdown]
# $x(a)$ denotes the ammount of flowers produced at time $t$. We normalize $t$ to be between zero and one. Thus domain of $x(\cdot)$ is $(0,1)$.

# %%
domain = np.arange(0.001, 1.0, 0.01)

# %% [markdown]
# We first define the probability of setting seed $p_x(\cdot)$, as follows:

# %%
#alpha, beta, k_function

# %%
def p_x(a, x, k):
    #takes a, and functions x and k
    return math.e**(-x[a]/k(a))

# %% [markdown]
# In the example, function $k(\cdot)$ is a time-dependent carrying capacity, given by $K(a)= 100(2 + \sin2 \pi ((a-1)^2 - \frac{1}{4}))$

# %%
def k(a):
    return 100*(2 + math.sin(2*math.pi*((a-1.0)**2.0 - 0.25)))

# %%
plot(domain, [k(a) for a in domain], label = 'K(a)')
plt.legend(loc='best')
plt.title(r'Carrying capacity $K(a)$')
plt.ylim((99, 305))
plt.xlabel('time')

# %% [markdown]
# We also consider a function $c(e)$, which denotes the factor in which competition affects the schedule of a competing individual. Here $e$, which is a function of a is the mutant's excess flowering. It is assumed that
#
# $c(e(a)) = 2 / (1 + \exp(-\alpha e(a)))$
#
#
# $\alpha$ determines the strenght of the asymmetric competition between mutant and resident.

# %%
def c(e, alpha):
    return 2.0/(1 + math.e**(-alpha*e))

# %% [markdown]
# The birth-rate of a a rare mutant with schedule $x'$ is given by:
#
# $b(x',x) = \int x'(a)c([x'(a)-x(a)]/x(a)^{\beta})p_x (a)da $
#
# Here $\beta$ measures the excess flowering intensity.

# %%
def birth(x_mutant, x_resident, domain, alpha, beta, k_function):
    x_resident_dict = dict(zip(domain, x_resident))
    x_mutant_dict = dict(zip(domain, x_mutant))
    integrand = [x_mutant_dict[a]*c((x_mutant_dict[a]-x_resident_dict[a])/(x_mutant_dict[a]**beta), alpha)*p_x(a, x_resident_dict, k_function) for a in domain]
    return simps(integrand, domain)

# %% [markdown]
# Since death rates are assume to be constant, we can define fitness solely in terms of birth rates:

# %%
def flowering_fitness(x_resident, x_mutant, domain, alpha, beta, k_function):
    fitness_resident = birth(x_resident, x_resident, domain, alpha, beta, k_function)
    fitness_mutant = birth(x_mutant, x_resident, domain, alpha, beta, k_function)
    return fitness_resident, fitness_mutant

# %%
initial_surface = np.ones_like(domain)

# %%
number_of_generations = 1000000

# %%
ans, series = evolve(initial_surface, mutation_function=point_mutation_distribution,iterations=number_of_generations,mutation_epsilon=0.01,domain= domain, fitness_function=flowering_fitness, alpha=1.0, beta=0.9, k_function=k)

# %%
plot(domain, ans)

# %%
plot(domain, ans)

# %%
ani = create_video_from_time_series(series, None, domain, filename='/Users/garcia/Desktop/flowering.mp4', approximate_number_of_frames=5000, record_every=100)

# %%
display_animation(ani)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = 1;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img2776717">
#     <br>
#     <input id="_anim_slider2776717" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="anim2776717.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim2776717.slower()">&#8211;</button>
#     <button onclick="anim2776717.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim2776717.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim2776717.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim2776717.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim2776717.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim2776717.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim2776717.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim2776717.faster()">+</button>
#   <form action="#n" name="_anim_loop_select2776717" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   var img_id = "_anim_img2776717";
#   var slider_id = "_anim_slider2776717";
#   var loop_select_id = "_anim_loop_select2776717";
#   var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAIABJREFUeJzt3X1wVPXZxvFrJcEaowTEgoSMvEUJErOJaMCGxw3KAEFT\
# VFRoR4KKRqpFdKy1tVVQ6yCdaUUYbOyAgFrsFN9oJShiNhUhRCVBFCugREN4UZSI4AshnOcPmy3Z\
# JBBwz8m54fuZYcaTPblzkp+Ti9+5dpeA4ziOAAAw5oS2vgAAAI4GAQYAMIkAAwCYRIABAEwiwAAA\
# JhFgAACTCDAAgEkEGADAJAIMAGASAQYAMIkAAwCYRIABAEwiwAAAJhFgAACTCDAAgEkEGADAJAIM\
# AGASAQYAMIkAAwCYRIABAEwiwAAAJhFgAACTCDAAgEkEGADAJAIMAGASAQYAMIkAAwCYRIABAEwi\
# wAAAJhFgAACTCDAAgEkEGADAJAIMAGASAQYAMIkAAwCYRIABAEwiwAAAJhFgAACTCDDExLfffqvs\
# 7GwFg0H169dPv/nNb5o9b9KkSUpNTVVGRoYqKio8vkoAx5K4tr4AHBt+9KMfqaSkRAkJCdq/f79y\
# cnK0YsUK5eTkRM5ZsmSJNm3apI0bN2r16tWaOHGiysrK2vCqAVjGDgwxk5CQIEnat2+f6uvr1alT\
# p0aPL168WAUFBZKk7Oxs1dbWaseOHZ5fJ4BjAwGGmDlw4ICCwaC6dOmi3Nxc9evXr9HjNTU1SklJ\
# iRx3795dW7Zs8foyARwjuIWImDnhhBNUWVmpL7/8UsOGDVM4HFYoFGp0juM4jY4DgUCTOc19DPZE\
# rzUQa+zAEHMdOnTQyJEj9dZbbzX6eHJysqqrqyPHW7ZsUXJycrMz7rvvPjmOE/M/1uZavOb77rvP\
# 1f+/gAYEGGJi586dqq2tlSR98803WrZsmTIzMxudk5+frwULFkiSysrKlJSUpC5dujQ7r6qqypXr\
# tDbXzdnW5gLRuIWImNi2bZsKCgp04MABHThwQNdee60uvvhiFRUVSZIKCwuVl5enJUuWqE+fPjr5\
# 5JP1xBNPtPFVA7As4HCjGj4TCAR06qmnavfu3W19KWiljh076osvvpAkhcNh5ebm0oHBdQQYfKfh\
# SRz8r2lHIBBotF7Rx4Ab6MAAxFQ4HG7rS8BxggDDcS0cDuvMM89Ubm6ucnNz9c9//rPVnztlyhQt\
